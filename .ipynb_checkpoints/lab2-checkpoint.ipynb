# %%
structure = {"Qiyas-01234" :
             {"family" :["Maraki", "Yonatan", "Henol", "Liyat"],
              "Friend" : ["sara","Lidiya","Feven"]}}
print(structure)
# Out:
# {'Qiyas-01234': {'family': ['Maraki', 'Yonatan', 'Henol', 'Liyat'], 'Friend': ['sara', 'Lidiya', 'Feven']}}

# %%
paragraph = "Detection mechanisms also also also a a serve not only to detect failures of preventive security controls which is perhaps their main function but also to provide a degree of assurance by demonstrating when the preventive controls are indeed operating and functioning as expected."

# %%
data = paragraph.lower().split()
srt = sorted(data)

# %%
print(srt)
# Out:
# ['a', 'a', 'a', 'also', 'also', 'also', 'also', 'and', 'are', 'as', 'assurance', 'but', 'by', 'controls', 'controls', 'degree', 'demonstrating', 'detect', 'detection', 'expected.', 'failures', 'function', 'functioning', 'indeed', 'is', 'main', 'mechanisms', 'not', 'of', 'of', 'only', 'operating', 'perhaps', 'preventive', 'preventive', 'provide', 'security', 'serve', 'the', 'their', 'to', 'to', 'when', 'which']

# %%
counts = {}
for i in srt:
      counts[i] = counts.get(i,0)+1
print(counts)
# Out:
# {'a': 3, 'also': 4, 'and': 1, 'are': 1, 'as': 1, 'assurance': 1, 'but': 1, 'by': 1, 'controls': 2, 'degree': 1, 'demonstrating': 1, 'detect': 1, 'detection': 1, 'expected.': 1, 'failures': 1, 'function': 1, 'functioning': 1, 'indeed': 1, 'is': 1, 'main': 1, 'mechanisms': 1, 'not': 1, 'of': 2, 'only': 1, 'operating': 1, 'perhaps': 1, 'preventive': 2, 'provide': 1, 'security': 1, 'serve': 1, 'the': 1, 'their': 1, 'to': 2, 'when': 1, 'which': 1}

# %%
import os

# %%
file = open("data.txt", "a", encoding = "utf-8")
for data in counts:
   file_data =f"{counts[data]}\n"
file.write(file_data)
# Out:
# 2

# %%
file = open("data.txt", "r", encoding = "utf-8")
print(file.read())
file.close()
# Out:
# which 		 1
# which 		 1
# 1

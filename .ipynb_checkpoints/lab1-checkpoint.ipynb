# %%
#tuple --> ( ) Data which is not going to be modified
data = (1,2,3,4,5,6)

# %%
data
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
data[3] = 123
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data[3] = 123
#
# TypeError: 'tuple' object does not support item assignment

# %%
#list --> [ ] Data can be modified
number = [1,2,3,4,5,6]

# %%
number
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
number[3] = 123

# %%
number
# Out:
# [1, 2, 3, 123, 5, 6]

# %%
del number[3]

# %%
number
# Out:
# [1, 2, 3, 5, 6]

# %%
number.pop()
# Out:
# 6

# %%
number
# Out:
# [1, 2, 3, 5]

# %%
number.append(7)

# %%
number
# Out:
# [1, 2, 3, 5, 7]

# %%
language = [ "c++", "java", "c#", "python", "javascript" ]

# %%
for i in language:
    print(i)
# Out:
# c++
# java
# c#
# python
# javascript

# %%
language[2]
# Out:
# 'c#'

# %%
language[1:4]
# Out:
# ['java', 'c#', 'python']

# %%
language[-2]
# Out:
# 'python'

# %%
language[-3:]
# Out:
# ['c#', 'python', 'javascript']

# %%
language[1:]
# Out:
# ['java', 'c#', 'python', 'javascript']

# %%
language[-4:-1]
# Out:
# ['java', 'c#', 'python']
